# %% [markdown]
# # let's add

# %%
1+2
# Out:
# 3

# %% [markdown]
# # 33

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
print(model)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.tsa.stattools import adfuller as ADF
from sklearn import datasets
from sklearn.linear_model import LinearRegression

# %%
iris=datasets.load_iris()
print(iris.data.shape)
# Out:
# (150, 4)

# %%
from sklearn import svm
clf=svm.LinearSVC()
clf.fit(iris.data,iris.target)
clf.predict([[5,3.6,1.3,0.25]])
clf.coef_
# Out:
# array([[ 0.18424561,  0.45122824, -0.80793997, -0.45071692],
#        [ 0.05102581, -0.8922205 ,  0.40598489, -0.93953723],
#        [-0.85060765, -0.98670513,  1.38107732,  1.86538115]])

# %%
from keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-9c5e0a19b646> in <module>()
# ----> 1 from keras.models import Sequential
#
# ModuleNotFoundError: No module named 'keras'

# %%
import matplotlib.pyplot as plt
x=np.linspace(0,10,1000)
y=np.sin(x)+1
z=np.cos(x**2)+1
plt.figure(figsize=(8,4))
plt.plot(x,y,label='$\sin x+1$',color='red',linewidth=2)
plt.plot(x,z,'b--',label='$\cos x^2+1$')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('title')
plt.ylim(0,2.2)
plt.legend()
plt.show()

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
model=Sequential()
model.add(Dense(640,activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
sgd=SGD(lr=0.1,decay=1e-6,momentum=0.9,nesterov=True)
model.compile(loss='mean-squared_error',optimizer=sgd)
model.fit(X_train,y_train,nb_epoch=20,batch_size=16)
score=model.evaluate(X_test,y_test,batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-23787399cbb6> in <module>()
#      10 sgd=SGD(lr=0.1,decay=1e-6,momentum=0.9,nesterov=True)
#      11 model.compile(loss='mean-squared_error',optimizer=sgd)
# ---> 12 model.fit(X_train,y_train,nb_epoch=20,batch_size=16)
#      13 score=model.evaluate(X_test,y_test,batch_size=16)
#
# NameError: name 'X_train' is not defined
